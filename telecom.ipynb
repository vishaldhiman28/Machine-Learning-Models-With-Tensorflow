# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
#header files
from __future__ import absolute_import, division, print_function, unicode_literals
try:
  # %tensorflow_version 2.x
except Exception:
  pass
import tensorflow as tf
from IPython.display import clear_output
import IPython

import pandas as pd 
import numpy as np
from IPython.display import clear_output
import IPython
import plotly.express as px
import plotly.offline as pyo
import plotly.io as pio

import plotly.graph_objects as go

pio.renderers.default = "colab"

# %%
#reading file from location
churn_data=pd.read_csv("Colab Notebooks/Churn.csv")

# %%
#data frame of churn_dataset

churn_data.head(5)
# Out:
#    customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0  7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1  5575-GNVDE    Male              0  ...          56.95       1889.5     No
# 2  3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 3  7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 4  9237-HQITU  Female              0  ...          70.70       151.65    Yes
#
# [5 rows x 21 columns]

# %%
print("[OUT]:Dataset shape:\n ",churn_data.shape)
# Out:
# [OUT]:Dataset shape:
#   (7043, 21)

# %%
#column names
print("[OUT]: Columns Name in the data:\n",churn_data.columns)
# Out:
# [OUT]: Columns Name in the data:
#  Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
print("[OUT]:Description of Missing values in dataset:\n\n ",churn_data.isnull().sum())
# Out:
# [OUT]:Description of Missing values in dataset:
#
#   customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
print("[OUT]:Data Info:\n",churn_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
# customerID          7043 non-null object
# gender              7043 non-null object
# SeniorCitizen       7043 non-null int64
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7043 non-null object
# ...

# %%
class Data_visual:
  def male_female(self):
    mf_count=churn_data['gender'].value_counts().rename_axis('Gender').reset_index(name='Gender_Count')
    fig = px.bar(mf_count, x='Gender', y='Gender_Count',title='Male and Female Customer Count',color='Gender', width=650, height=450)
    fig.show()
    
    
    female_ch=churn_data[churn_data['gender']=='Female']['Churn'].value_counts().rename_axis('Churn').reset_index(name='Count',)
    fig = px.bar(female_ch, x='Churn', y='Count',title='Female Churn Count',color='Churn',width=650, height=450)
    fig.show()
    
    male_ch=churn_data[churn_data['gender']=='Female']['Churn'].value_counts().rename_axis('Churn').reset_index(name='Count')
    fig = px.bar(male_ch, x='Churn', y='Count',title='Male Churn Count',color='Churn',width=650, height=450)
    fig.show()
    
  def senior_cit(self):
    senior_=churn_data['SeniorCitizen'].value_counts().rename_axis('Label').reset_index(name='No_of_Customer')
    senior_['Senior_Citizen']=['No','Yes']
    fig= px.bar(senior_,x='Senior_Citizen',y='No_of_Customer',title='Senior Citizen Persent as Customer',color='Senior_Citizen',width=650,height=450)
    fig.show()
                
  def phone_service(self):
    ph_count=churn_data['PhoneService'].value_counts().rename_axis('Phone_Service').reset_index(name='No_of_Customer')
    fig= px.bar(ph_count,x='Phone_Service',y='No_of_Customer',title='Stats of Customer Having Phone Service',color='Phone_Service',width=650,height=450)
    fig.show()            
    ph_churn=churn_data[churn_data['PhoneService']=='Yes']['Churn'].value_counts().rename_axis('Churn').reset_index(name='Count')
    fig= px.bar(ph_churn,x='Churn',y='Count',title='Stats of Customer Having Phone Service and Churn ',color='Churn',width=650,height=450)
    fig.show()  
  
  def internet_service_type(self):
    service_in=churn_data['InternetService'].value_counts().rename_axis('Internet_Service').reset_index(name='No_of_Customer')
    fig= px.bar(service_in,x='Internet_Service',y='No_of_Customer',title='Stats of Customer Having Type of Internet Service',color='Internet_Service',width=650,height=450)
    fig.show()   
    
  def multiple_lines(self):
    multi_line=churn_data['MultipleLines'].value_counts().rename_axis("Multiple Lines").reset_index(name='No_of_Customer')
    fig= px.bar(multi_line,x='Multiple Lines',y='No_of_Customer',title='Stats of Customer Having Multtple Lines of Service',color='Multiple Lines',width=650,height=450)
    fig.show() 
  
  def contract(self):
    contract=churn_data['Contract'].value_counts().rename_axis("Contract Type").reset_index(name='No_of_Customer')
    fig= px.bar(contract,x='Contract Type',y='No_of_Customer',title='Stats of Customer HavingType of Contract',color='Contract Type',width=650,height=450)
    fig.show() 
    
  def monthly_charges(self):
    m_charges=churn_data['MonthlyCharges'].unique()
    
    x=range(0,len(m_charges))
    d=zip(x,m_charges)
    df=pd.DataFrame(d,columns=['Unique Charges','Monthly Charge'])
    fig= px.scatter(df,x='Unique Charges',y='Monthly Charge',title='Stats of Customers Monthly Charge',width=650,height=450)
    fig.show() 
  
  def churn_dat(self):
    contract=churn_data['Churn'].value_counts().rename_axis("Churn (Yes/No)").reset_index(name='Count')
    fig= px.bar(contract,x='Churn (Yes/No)',y='Count',title='Stats of Churn',color='Churn (Yes/No)',width=650,height=450)
    fig.show() 
    
obj=Data_visual()

# %%
obj.churn_dat()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7b96649e-c186-4e0f-9420-ab47a7932bc0" class="plotly-graph-div" style="height:450px; width:650px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7b96649e-c186-4e0f-9420-ab47a7932bc0")) {
#                     Plotly.newPlot(
#                         '7b96649e-c186-4e0f-9420-ab47a7932bc0',
# ...

# %%
obj.monthly_charges()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3b7166d9-4495-4c8c-a893-1d9f9e1abb1b" class="plotly-graph-div" style="height:450px; width:650px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3b7166d9-4495-4c8c-a893-1d9f9e1abb1b")) {
#                     Plotly.newPlot(
#                         '3b7166d9-4495-4c8c-a893-1d9f9e1abb1b',
# ...

# %%
obj.contract()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1f9d50c8-d65e-45ef-9fb6-f9c790ab3182" class="plotly-graph-div" style="height:450px; width:650px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1f9d50c8-d65e-45ef-9fb6-f9c790ab3182")) {
#                     Plotly.newPlot(
#                         '1f9d50c8-d65e-45ef-9fb6-f9c790ab3182',
# ...

# %%
obj.multiple_lines()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5cc27fb4-e470-44d7-b5bb-8a4aa9889204" class="plotly-graph-div" style="height:450px; width:650px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5cc27fb4-e470-44d7-b5bb-8a4aa9889204")) {
#                     Plotly.newPlot(
#                         '5cc27fb4-e470-44d7-b5bb-8a4aa9889204',
# ...

# %%
obj.internet_service_type()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d880852a-ea00-46c8-bc3c-0ce46b760129" class="plotly-graph-div" style="height:450px; width:650px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d880852a-ea00-46c8-bc3c-0ce46b760129")) {
#                     Plotly.newPlot(
#                         'd880852a-ea00-46c8-bc3c-0ce46b760129',
# ...

# %%
obj.phone_service()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="474090d3-7c05-4939-a256-bfefe7fdcb19" class="plotly-graph-div" style="height:450px; width:650px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("474090d3-7c05-4939-a256-bfefe7fdcb19")) {
#                     Plotly.newPlot(
#                         '474090d3-7c05-4939-a256-bfefe7fdcb19',
# ...

# %%
obj.senior_cit()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d0a05d67-be4d-4e5d-9726-76e913bef4f6" class="plotly-graph-div" style="height:450px; width:650px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d0a05d67-be4d-4e5d-9726-76e913bef4f6")) {
#                     Plotly.newPlot(
#                         'd0a05d67-be4d-4e5d-9726-76e913bef4f6',
# ...

# %%
obj.male_female()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8caba4f6-9d14-46fd-941d-ce9482ed8f79" class="plotly-graph-div" style="height:450px; width:650px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8caba4f6-9d14-46fd-941d-ce9482ed8f79")) {
#                     Plotly.newPlot(
#                         '8caba4f6-9d14-46fd-941d-ce9482ed8f79',
# ...

# %%
label=churn_data['Churn']
label=label.map(lambda x: 1 if x=="Yes" else 0)
del churn_data['Churn']
del churn_data['customerID']

X_train,X_test,y_train,y_test=churn_data[:4000],churn_data[4000:],label[:4000],label[4000:]
print("[OUT]:length of trainig set: ",len(X_train))
print("[OUT]:length of test set: ",len(X_test))
print("[OUT]:length of trainig  label set: ",len(y_train))
print("[OUT]:length of test label set: ",len(y_test))

X_train
# Out:
# [OUT]:length of trainig set:  4000
# [OUT]:length of test set:  3043
# [OUT]:length of trainig  label set:  4000
# [OUT]:length of test label set:  3043
#       gender  SeniorCitizen  ... MonthlyCharges TotalCharges
# 0     Female              0  ...          29.85        29.85
# 1       Male              0  ...          56.95       1889.5
# 2       Male              0  ...          53.85       108.15
# 3       Male              0  ...          42.30      1840.75
# 4     Female              0  ...          70.70       151.65
# 5     Female              0  ...          99.65        820.5
# 6       Male              0  ...          89.10       1949.4
# 7     Female              0  ...          29.75        301.9
# 8     Female              0  ...         104.80      3046.05
# 9       Male              0  ...          56.15      3487.95
# 10      Male              0  ...          49.95       587.45
# 11      Male              0  ...          18.95        326.8
# ...

# %%
print("\n[Out] Making Feature Column:")

fc = tf.feature_column
Categorical_col = ['gender','Partner','Dependents','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV',
'StreamingMovies','PaperlessBilling']
Numerical_col = ['MonthlyCharges','tenure','SeniorCitizen']

def one_hot_cat_column(feature_name, vocab):
  return fc.indicator_column(fc.categorical_column_with_vocabulary_list(feature_name,vocab))
feature_column = []
for feature_name in Categorical_col:
  # Need to one-hot encode categorical features.
  vocabulary = X_train[feature_name].unique()
  feature_column.append(one_hot_cat_column(feature_name, vocabulary))

for feature_name in Numerical_col:
  feature_column.append(fc.numeric_column(feature_name,dtype=tf.float32))

print("\n[Out] Making of  Feature Column done.")
# Out:
# [Out] Making Feature Column:
#
# [Out] Making of  Feature Column done.

# %%
size_of_batch = len(y_train)
def make_input_fn(X, y, n_epochs=None, shuffle=True):
  def input_fn():
    dataset = tf.data.Dataset.from_tensor_slices((dict(X),y))
    if shuffle:
      dataset = dataset.shuffle(size_of_batch)
    # For training, cycle thru dataset as many times as need (n_epochs=None).
    dataset = (dataset.repeat(n_epochs).batch(size_of_batch))
    return dataset
  return input_fn

# Training and evaluation input functions.
train_shuffle = make_input_fn(X_train,y_train)
test_shuffle =make_input_fn(X_test,y_test,n_epochs=1,shuffle=False)

# %%
#boosted classifier
n_batch=5
est = tf.estimator.BoostedTreesClassifier(feature_column,n_batches_per_layer=n_batch,n_trees=100,max_depth=8)
# Train model.

print("\n[OUT]:model trainig starts:")
est.train(train_shuffle,max_steps=150)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpkg8kus8v
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpkg8kus8v', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# ...

# %%
print("\n[OUT]:model trainig end.")

print("\n[OUT]:model evaluation starts:")
results = est.evaluate(test_shuffle)
print("\n[OUT]:model evaluation end:")
clear_output()
pd.Series(results).to_frame()
# Out:
#                                0
# accuracy                0.790010
# accuracy_baseline       0.733158
# auc                     0.810760
# auc_precision_recall    0.619003
# average_loss            0.451693
# label/mean              0.266842
# loss                    0.451693
# precision               0.653641
# prediction/mean         0.264052
# recall                  0.453202
# global_step           150.000000
